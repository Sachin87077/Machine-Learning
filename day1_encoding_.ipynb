# %%
#data is divide ito two categroies num/category cartgeoru into nominal /ordinal ....in ordinak thre is relationsjio[ with dta
#in nomiln ther s no realtion ] in nomnial we use one hot endcodig  ordinal usese ordinl encoding or label encoding

# %%
import numpy as np
import pandas as pd


df = pd.read_csv('customer.csv')

# %%
df.sample(5) #gender nominal  (no order ) one hot encoding,,,,review ordinal(order matter ) education ordinal   so here ordinal ecoder  purhase dlabel encoder
 #now here we ahcve to sepatert vrevie and edu for apling  ordila encodng and peruchase forlabel encodmig(only for output column
# Out:
#     age  gender review education purchased
# 36   34  Female   Good        UG       Yes
# 40   39    Male   Good    School        No
# 6    18    Male   Good    School        No
# 17   22  Female   Poor        UG       Yes
# 48   39  Female   Good        UG       Yes

# %%
df = df.iloc[:,2:]

df.head()
# Out:
#   purchased
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3499598564.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test= train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
# ...
